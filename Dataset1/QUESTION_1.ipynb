# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("cleaned_primary_school_GDP.csv")
df
# Out:
#           Country                                          Indicator     Sex  \
# 0       Australia  Proportion of students at the end of primary a...  Female
# 1       Australia  Proportion of students at the end of primary a...    Male
# 2       Australia  Proportion of students at the end of primary a...   Total
# 3         Austria  Proportion of students at the end of primary a...   Total
# 4         Austria  Proportion of students at the end of primary a...  Female
# ..            ...                                                ...     ...
# 424  South Africa  Out-of-school rate for children of primary sch...   Total
# 425  South Africa  Out-of-school rate for children of primary sch...   Total
# 426  South Africa  Out-of-school rate for children of primary sch...   Total
# 427  South Africa  Proportion of students at the end of primary a...   Total
# 428  South Africa  Proportion of students at the end of primary a...   Total
#
# ...

# %%
#Which wealth quintile has the highest completion rate for primary education in each country?


df2= df[df["Indicator"]=="Completion rate for children of primary school age"]
df3 = df.set_index("Wealth Quintile")
df3 = df3.drop("Total")


df4 = df3.groupby(['Country','Wealth Quintile']).sum()
df4[['Value']]
# Out:
#                                    Value
# Country      Wealth Quintile
# Brazil       Fourth           193.234806
#              Highest          194.868911
#              Lowest           185.848040
#              Middle           191.797998
#              Second           190.215932
# Colombia     Fourth           192.592265
#              Highest          195.596648
#              Lowest           180.151666
#              Middle           191.488963
#              Second           188.598711
# Costa Rica   Fourth           195.964359
#              Highest          198.315652
#              Lowest           192.071109
#              Middle           193.637038
#              Second           196.501907
# India        Fourth           197.161000
#              Highest          198.732000
#              Lowest           182.299000
#              Middle           195.039000
#              Second           192.254000
# Indonesia    Fourth           193.489451
# ...

# %%
letter_pivot = pd.pivot_table(
    df3, index='Country', columns='Wealth Quintile', values='Value', aggfunc='sum'
)
#letter_pivot

letter_pivot.plot.barh(figsize=(15, 15))
# Out:
# <AxesSubplot:ylabel='Country'>
